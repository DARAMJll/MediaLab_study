# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
year_array = np.array([2011,2012,2013,2014,2015,2016,2017,2018,2019,2020])

stok_array = np.array([14.46,19.01,20.04,27.59,26.32,28.96,42.31,39.44,73.41,132.69])

# %%
plt.plot(year_array, stok_array)
plt.show()

# %%
name_array = np.array(['mark', 'dongwook', 'hyojune', 'sowon', 'taeho'])
votes_array = np.array([5, 10, 6, 8, 3])

# %%
plt.bar(name_array, votes_array)
plt.show()

# %%
height_array = np.array([
    165,164,155,151,157,162,155,157,165,162,165,167,167,183,180,184,177,178,175,181,172,173,169,172,177,178,185,186,190,187
])

weight_array = np.array([62,59,57,55,60,58,51,56,68,64,57,58,64,79,73,76,61,65,83,80,67,82,88,62,61,79,81,68,83,80])

# %%
plt.figure(figsize = (10, 4))
plt.scatter(height_array, weight_array, c = 'red', marker = '+') #산점도 표 /색을 커스텀하고싶으면 # 하고 색상코드
plt.rc('font', family = 'Malgun Gothic')
plt.title('Height and Weight')
plt.xlabel('Height(cm)')
plt.ylabel('Weight(kg)')

plt.show()
